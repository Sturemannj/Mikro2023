# %% [markdown]
# # SOK-1006 V23
# ## Mappeoppgave 2 - Innføring av bompenger i Tromsø: Effekt på bilisters atferd og velferd
# ### Kandidatnr 81
#
#
# ## GithubLenke: https://github.com/Sturemannj/Mikro2023
#
#
# ### Kapittel 1 - Innledning
#
# Denne toppsiden av oppgaven skal vi se nærmere på bompengeavgifter som krever en avgift ved passering av en bomstasjon på vei, bror eller tunnel. Et formål med en bompengeavgift er å finansiere bygging, drift og vedlikehold av infrastrukturprosjekter som veier, sykkelvei eller kollektivtransport.
#
# I sin helhet kan vi se at bakgrunnen for innføring av bompengeavgifter er første er det et økende behov for finansiering av vei og infrastruktur i Norge. Uten bompengeavgift er det ingen gode tradisjonelle midler til å dekke kostnadene for infrastruktur for veier. Bompengeavgifter kan også brukes som en fremtidig finansieringskilde for å sikre en god inntekt på viktige prosjekter for fremtiden.
#
# I tillegg til dette er bompengeavgift virkemiddel for å redusere trafikkbelastning og fremme en miljøvennlig transport framgang. Det var kreve inn avgifter ved å passere posisjonen kan det motivere eller i alle fall demotivere enkelte mennesker til å bruke penger ved å passere disse bomstasjonene og heller ville velge å ta en vri på sin framgangsmåte som sykkel, samkjøring eller kollektivtransport. Dette vil da redusere antall kjøretøy på veien, så vil da hjelpe med å redusere eller luftforurensning og trafikkproblemer som kan oppstå.
#
# Bompengeavgiftene er allerede godt brukt over flere byområder i Norge som Oslo, Bergen, Stavanger og Trondheim. Disse bomringene har jobbet på å dekke kostnader for infrastruktur men også hjelper til å finansiere fremtidige prosjekter. Og noen av disse byene som har en større miljø virksomhet enn andre byer i Norge har hjulpet ved å redusere antall transport som går igjennom disse tettbebygde byene.
#
# Ut ifra dette så er det altså bompengeavgift et politisk spørsmål som er gjenstand for debatt, der noen politikere har partier som har valgt å redusere og fjerne bompengeavgiften, dens andre argumenterer for behovet for å øke antall bomstasjoner for å redusere antall biler på veiene.
#
# I Tromsø ble etablert bomstasjoner som en del av bompengeordningen, denne bompengeordningen er innført for å finansiere utbygging av Veiforbindelser som inkluderer utvidelse av gårds sykkelveier, kollektivtiltak og tunneler i Tromsø.
#
# Vet du hva Tromsø har slitet med store køproblemer og fremgangsmåter rundt om øya, så valgte bompengeordningen og mot dere 15 bomstasjoner for å dekke hele kretsen til Tromsøya.
#
# Dermed valgte Tromsø å bruke autopass-systemet for å sikre automatisk registrering av passeringer gjennom bomstasjonene. Autopass er da et elektronisk system som brukes i Norge for å forenkle effektiviteten i innkreving av bompenger. Det brukes en autopass brikke som plasseres i foruten på kjøretøyet, der brikken automatisk identifiserer brikkens unike identifikasjon til å registrere passerende kjøretøy i disse 15 bomstasjonene. Autopass brukes også i andre området i Norge slik at bilister kan bruke dette bomstasjonen systemet i alle fremkomne byer de skal passere. Dette systemet gir også muligheten for rabattordninger basert på faktorer på tidspunkt på dagen, type kjøretøy eller miljøvennlighet. I dette eksempelet kan vi se på at elbiler eller kjøretøy med lavere utslipp vil være fritatt fra enkelte bomavgifter rundt om i landet.
#
# bompengesystemet er operert slik at det er toveis innkreving, dette betyr at man betaler bompenger for både inn og utkjøring. Da kan det er viktig å merke seg at man kunne betaler for en passering per time selv om man kjører noen flere kompensasjoner. Så person en skal kjøre fra den ene siden av Tromsø til den andre side i løpet av at en time betaler han for hele én bomstasjon på den timen. Dette gjelder da kun for de som har autopassavtale. Det er månedlig tak kven som er satt for å begrense bompenger til maksimalt 80 passeringer per måned takk Jensen gjelder for alle kalendermåneder kun for de som har autopassavtale dersom man har flere passeringer enn 80 i løpet av måned blir man kun belastet av de første 80 passeringene. Dermed i rushtiden opererer bomstasjoner med dobbel takst. Dette er da fra mandag til fredag mellom 06:30 og 09:00 – 15:00 og 17:00. Rushtiden da gjelder ikke på helligdager og offisielle fridager, med dette så er det viktige faktorer å ta i betraktning når man skal ha planlegging av reiser i Tromsø eller andre steder med tilsvarende system. Disse reglene da knyttet til bompengesystemet som kan hjelpe oss forstå kostnad ved bruk av veiene i Tromsø og andre områder blir liggende bompengeordninger.

# %%
# Takstgruppe 1 - Kjøretøy under 3,5 tonn
takstgruppe_1_header = "|                     | Bensin, diesel og ladbar hybrid |                      | Nullutslipskjøretøy |                      |"
takstgruppe_1_separator = "|---------------------|:------------------------------:|---------------------:|---------------------:|----------------------|"
takstgruppe_1_rows = [
    "|                     | Fullpris                       | Gyldig avtale og brikke | Fullpris            | Gyldig avtale og brikke |",
    "| Alle bomstasjoner (15) | 12,00                          | 9,60                  | 12,00               | 4,80                   |"
]

# Rushtidsavgift 06:30-09:00 og 15:00-17:00
rushtidsavgift_header = "|                     | Bensin, diesel og ladbar hybrid |                      | Nullutslipskjøretøy |                      |"
rushtidsavgift_separator = "|---------------------|:------------------------------:|---------------------:|---------------------:|----------------------|"
rushtidsavgift_rows = [
    "|                     | Fullpris                       | Gyldig avtale og brikke | Fullpris            | Gyldig avtale og brikke |",
    "| Alle bomstasjoner (15) | 36,00                          | 28,80                 | 36,00               | 14,40                  |"
]

# %% [markdown]
# Prisene får transportkostnader utgjør selve kostnaden for bilister som må betale. Disse kostnadene inkluderer da pengekostnadene for bompenger, drivstoff, parkering og eventuelle andre avgifter. På dette inkluderer er det transportkostnader og reisekostnader for å bruke transportmidlet. Endringer i priser kan også ha betydning på flere områder. En økning i pris kan påvirke hvor hyppige en person velger å reise. Hvis kostnader skal øke kan det hende at personer beregner reiseaktiviteten sin for å bruke mindre penger. Prisendringene kan også påvirke hvilken rute en person velger å ta. Hvis det er en annen rute som kan være billigere og har lavere kostnader knyttet til seg kan folk heller velge å bruke en annen rute for å komme seg fra A til Å.
#
# Tidspunkter før reisen kan påvirkes av prisendringer, så om perioder det er prisen kan være høyere på grunn av eventuelt rushtider blir folk ser på alternativer for reise etter andre tidspunkter eller andre transportør midler. Transporttypen har også en påvirkning på pris, hvis prisen på eventuelle kjøretøy av forskjellige klasser øker vil folk se på andre alternativer for å ta sporter seg selv mer effektivt. Hvis vi skal vurdere en prisendring for et forbruk, kan vi bruke elastitet da er det er mål på hvor følsom forbruket er for endringen i pris. Det vil da regnes som en endring i forbruket følge opp en prosents økning.

# %% [markdown]
# ### Kapittel 2 - Trafikkbildet i Tromsø før og etter innføring av bompenger

# %%
import pandas as pd
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
def process_traffic_data(file_path):
    # Les csv-filen
    traffic_data = pd.read_csv(file_path, sep=',', encoding= 'unicode_escape')
    # Fjern unødvendige kolonner
    columns_to_drop = ['Unnamed: 0','Fra','Til','Vegreferanse','Felt']
    traffic_data.drop(columns_to_drop, inplace=True, axis=1)
    # Pivoter dataframen
    traffic_data = traffic_data.pivot(index = 'Dato', columns= 'Navn', values = 'Trafikkmengde')
    # Fjern kolonneakser
    traffic_data = traffic_data.rename_axis(None, axis=1)
    # Reset indeksen
    traffic_data = traffic_data.reset_index()
    # Konverter 'Dato' kolonnen til datetime
    traffic_data['Dato']= pd.to_datetime(traffic_data['Dato'])
    return traffic_data
Trafikkmengde_etter_bompenger = process_traffic_data('Bompenger 3.csv')

# %%
sns.set_style('whitegrid')
#Lager plott med veridene
fig, ax = plt.subplots(figsize=(15, 8))
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.set_xlabel('Dato', fontsize=14) 
ax.set_ylabel('Trafikkmengde', fontsize=14)  
ax.plot(Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['TROMSØBRUA'], 
        label='Tromsøbrua', linewidth=2, linestyle='-', color='green', marker='o')
ax.plot(Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['Sandnessundbrua'], 
        label='Sandnessundbrua', linewidth=2, linestyle='--', color='red', marker='v')

ax.legend(fontsize=12) 
ax.xaxis.set_tick_params(labelsize=12, rotation=20) 
ax.yaxis.set_tick_params(labelsize=12)

# %% [markdown]
# Figuren over viser trafikk med mellom tromsøbrua og sandnessundbrua over tid etter innføring av bompenger, hvis vi sammenligner disse 2 broene kan vi få en oversikt i endringer i trafikkmengde og mønstre og effektiviteten av bompengene.
#
# Er basert på observasjonene så kan vi se at perfekt men mengden varierer over tid for hver bro det gir oss en informasjon på eventuelle endringer i brukernes preferanse på hvilke bruer de velger å bruke. Du ser på effekten av bompengene så kan vi se at innføring av bompenger har hatt en innvirkning på trafikkmengden der vi ser en trend i trafikkmengdene etter innføring. Dette kan også bety at andre bilister velger andre alternativer ruter etter transportmetoder og mengden trafikk. Det kan være viktig å legge merke til at figuren har en observasjon som kan variere avhengig av konteksten av den spesielle informasjon jeg har fått av brune. Ettersom brune er passert på under en time tidsrom mellom hverandre så er muligheten for å kunne passere begge brune under en time ved ganske stor. I helhet så kan vi se endringer i trafikkmengde etter innføringen. Så kan vi observere forskjellen mellom Tromsø bruene ettersom man den ene broen kommer direkte fra fastlandet og andre kommer fra Kvaløya.  Vi kan se også endring i tid, figuren viser at  mengden utvikler seg over tid ettersom hvilken tid på Dagen der og hvilken sesong det er.

# %%
fig, ax = plt.subplots(figsize=(15, 8))  
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.set_ylabel('Trafikkmengde')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['BREIVIKA'],
    color='blue')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['TROMSØBRUA'],
    color='green')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['Sandnessundbrua'],
    color='orange')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['Fartstavle Tverrforbindelsen'],
    color='purple')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['Kvaløyvegen'],
    color='red')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['Stakkevollvegen'],
    color='brown')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['Hansine Hansens veg'],
    color='gray')
ax.stackplot(
    Trafikkmengde_etter_bompenger['Dato'], Trafikkmengde_etter_bompenger['Strandvegen'],
    color='pink')

ax.legend(['Breivika', 'Tromsø Brua', 'Sandnessundbrua', 'Tverrforbindelsen', 'Kvaløyvegen', 'Stakkevollvegen', 'Hansine Hansens veg', 'Strandvegen'],
          bbox_to_anchor=(1.2, 0.7)) 
ax.xaxis.set_tick_params(labelsize=9, rotation=20)
plt.tight_layout()

# %% [markdown]
# I figuren over så kan vi observere trafikkmengden på ulike veier i Tromsø der bompengene storm. Hver av fargene representerer en bestemt vei og høyden av stabelen indikerer en trafikkmengde.
# Hvis vi observerer figuren kan vi si at Breivika er den store dominant ettersom trafikkmengde i alle tidspunkter dette året er størst etterfulgt av tromsøbrua sine passeringer det er trafikkmengden er relativt høy. Laveste grafikkbaserte bompasseringen ligger på strandveien og kvaløyveien. Disse 2 har du minst passerende.

# %%
#Laster inn data
månedstrafikk = pd.read_csv('MND-T.csv', sep=';')
månedstrafikk = (
    månedstrafikk
    .loc[månedstrafikk.Felt == 'Totalt', ['År','Måned','Trafikkmengde','Navn']]
    .rename(columns={'År':'YEAR','Måned' : 'MONTH', 'TROMSØBRUA': 'Tromsø Brua'})
)
månedstrafikk['Dato'] = pd.to_datetime(månedstrafikk[['YEAR', 'MONTH']].assign(DAY=1))
månedstrafikk = månedstrafikk.drop(['YEAR','MONTH'], axis=1)
månedstrafikk['Dato'] = pd.to_datetime(månedstrafikk['Dato'])

# %%
from sklearn.linear_model import LinearRegression
pd.options.mode.chained_assignment = None  # Fjerner false-positive warning.
månedstrafikksum = månedstrafikk.groupby(['Dato'])['Trafikkmengde'].sum()
månedstrafikksum = månedstrafikksum.to_frame()
månedstrafikksum = månedstrafikksum.reset_index()
månedstrafikk2022 = månedstrafikksum[månedstrafikksum['Dato'] < '2023-01-01']
månedstrafikk2023 = månedstrafikksum[månedstrafikksum['Dato'] >= '2023-01-01']

#regresjon av verdier før bompenger
månedstrafikk2022['Time'] = np.arange(len(månedstrafikk2022.index))
X = månedstrafikk2022.loc[:, ['Time']] 
y = månedstrafikk2022.loc[:, 'Trafikkmengde']
model = LinearRegression()
model.fit(X, y)
y_pred = pd.Series(model.predict(X), index=X.index)

#regresjon av verdier etter bompenger
månedstrafikk2023['Time'] = np.arange(len(månedstrafikk2023.index))
X2 = månedstrafikk2023.loc[:, ['Time']] 
y2 = månedstrafikk2023.loc[:, 'Trafikkmengde']
model = LinearRegression()
model.fit(X2, y2)
y_pred2 = pd.Series(model.predict(X2), index=X2.index)

#Lager selve plottet
fig, ax = plt.subplots(figsize=(12, 8))
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.set_ylim(60000, 110000)
ax.set_title('Trafikkmengde på sentrale punkter før og etter bompenger', fontsize=16)
ax.plot(månedstrafikk2022['Dato'], månedstrafikk2022['Trafikkmengde'], marker='o', linewidth=2, color='maroon', label='Før bompenger')
ax.plot(månedstrafikk2023['Dato'], månedstrafikk2023['Trafikkmengde'], marker='o', linewidth=2, color='darkgreen', label='Etter bompenger')
ax.plot(månedstrafikk2022['Dato'], y_pred, linewidth=2, color='darkred', label='Regresjon før bompenger')
ax.plot(månedstrafikk2023['Dato'], y_pred2, color='green', label='Regresjon etter bompenger')
ax.xaxis.set_tick_params(labelsize=9, rotation=20) 
ax.legend(loc='best', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Figuren vi ser over viser trafikk mellom alle passeringspunktene i Tromsø etter innføring av bompenger og for bompenger. Figurnavnet kan gis et godt bilde av trafikken.
#
# En observasjon fra figuren jeg så kan vi se at trafikkmengden etter 2023 er relativt lavere en før. Den grønne linjen representerer da regresjoner, for 2022 og 2023. Disse linjene gjør tydelig for at trafikkmengdene er relativt redusert etter innføring av bompenger. Vi kan også se at regresjonen for 2022 har en økende trend i trafikkmengden mens regresjonen for 2023 er nesten flat.
#
# Hvis vi ser sammenligningen på trafikkmengden før og etter innføring av bompenger kan vi se en tydelig nedgang i trafikk. Dette kan indikere at noen bilister har valgt alternative ruter etter transportmetoder for å unngå å betale bompenger. Reduksjonen kan resultere med økt kostnad, endringer i reisevaner eller andre faktorer. Tolkning av figuren Er avhengig av observasjonene i spesifikke kontekster og tilgjengelig informasjon av trafikkmengden og bompenger som er gitt. Andre faktorer av sesongvariasjoner, hendelser eller endringer i transportinfrastruktur kan påvirke trafikkmønstre og dette kan være lurt å ta i betraktning.

# %%
df_buss = pd.read_csv("https://raw.githubusercontent.com/uit-sok-1006-v23/uit-sok-1006-v23.github.io/main/data/antall%20p%C3%A5stigende.csv", parse_dates=['date'], dayfirst=True)

#Før bompenger
df_buss2022 = df_buss[(df_buss['date'] >= '2022-01-01') & (df_buss['date'] <= '2022-12-31')]
df_buss2022 = df_buss2022.groupby(df_buss2022['date'].dt.strftime('%B'))['Påstigende'].sum().to_frame().reset_index()
df_buss2022['Påstigende'] = df_buss2022['Påstigende'].div(10000)
months = ["January","February","March","April"]
df_buss2022 = df_buss2022[df_buss2022['date'].isin(months)]
df_buss2022['date'] = pd.Categorical(df_buss2022['date'], categories=months, ordered=True)

#Etter bompenger
df_buss2023 = df_buss[(df_buss['date'] >= '2023-01-01') & (df_buss['date'] <= '2023-12-31')]
df_buss2023 = df_buss2023.groupby(df_buss2023['date'].dt.strftime('%B'))['Påstigende'].sum().to_frame().reset_index()
df_buss2023['Påstigende'] = df_buss2023['Påstigende'].div(10000)
df_buss2023 = df_buss2023[df_buss2023['date'].isin(months)]
df_buss2023['date'] = pd.Categorical(df_buss2023['date'], categories=months, ordered=True)

#Lager Søyle plott
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(15, 8))
ax.bar(df_buss2022['date'], df_buss2022['Påstigende'], width=0.4, color='#006400', edgecolor='black', hatch='/', label='Før bompenger') #Før bompenger
ax.bar(df_buss2023['date'], df_buss2023['Påstigende'], width=0.4, color='#8B0000', edgecolor='black', hatch='\\', label='Etter bompenger', align='edge') #Etter bompenger

#Setter tittel og legende
ax.set_title('Påstigende buss - 2022 og 2023', fontsize=16, fontweight=0, color='black', y=1.05)
ax.legend(loc='upper left')

#Justerer layout
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'April'),
#   Text(1, 0, 'February'),
#   Text(2, 0, 'January'),
#   Text(3, 0, 'March')])

# %% [markdown]
# Kollektivtransport viser et alternativ til personbiltransport der endringer prisen påvirker vanligvis etterspørselen etter transportmiddelet. Figuren viser antall påstigende passasjerer på bussen før og etter innføringen av bompenger. Verdiene er delt på 10 000 som 80 viser 800 000.
#
# Vend opp grundig observasjon av figuren kan vi se antall påstigende passasjerer har økt fra 2022 til 2023. Spesielt i januar har antallet økt med nesten 64% noe som representerer betydelig økning fra året før. Dette kan eventuelt indikere at flere velger bruker kollektivtransportmiddel for så stutt for personbiltransport etter innføringen av bompenger. Økningen i passasjerer kan være en effekt av endringer i priser som kan tyde på alternativ valg som er mer attraktivt for folk i Tromsø.
#
# Her er det også viktig å observere at observasjonene kan være påvirket av faktorer på etterspørselen etter kollektivtransport som rutetilbudet, befolkningsvekst eller endring i byplanlegging. Får en mer detaljert analyse bør det konkluderes med flere tidsperioder over en lengre periode og mer nøyaktig data for et bedre resultat.

# %% [markdown]
# ### Kapitell 3
# Modellen vi skal bruke nå er en forenkling av virkelighets perspektiv. Da er jeg nede på med seg ut konsumenten tar valg mellom 2 goder, og i dette tilfellet så er det målt i kroner. 19 av konsum er kun avhengig av det individuelle konsumet. Prisene som må vises anses at de kan være gitt og konsumenten har oversikt over egent gode. Inntekten til konsumenten brukes til konsum dette er uten av hensyn til sparing. Formålet vil da komme til at konsumenten vil maksimere sin nytte ved å konsumere så mye som mulig.
#
# I modellen har konsumenten muligheten til å velge mellom andre koder og anta kilometer som de har kjørt, disse er da gjort i kroner som at det kan måles med samme skala. Andre goder er en pris på én mens antall kilometer kjørt er omregnet til en pris per kilometer kjøring. Budsjett betingelser er viktig del av modellen, dere viser at kostnadene for gode en og 2 må være lik inntekt til konsumenten. For å tegne en budsjettlinje trenger vi et budsjett, så et estimat for konsumenten daglige budsjett vil være gjennomsnittsinntekt i 2022, ifølge SSB og så var dette 664 680kr. Prisen for gode 1 per kilometer fort innføring av bompenger kan være 3,03kr basert på tall fra transportøkonomisk institutt. Etter innføringen av bompenger kan kostnaden per kilometer beregnes ved å legge til kostnad som påføres bilistene, et godt eksempel her ligger på 366kr per måned, og dette skal også deles på antall dager og antall kilometer kjørt per dag, da vil kostnaden for bompenger ligge på 3,61kr

# %%
def budsjett(M, p1, p2, x1):
    return M/p2 - p1*x1/p2

x = np.linspace(0.001, 1000, 1000)
def create_ax():
    sns.set(style='whitegrid') 
    fig, ax = plt.subplots()
    ax.set_ylabel('$x_2$', loc='top', rotation=0)
    ax.set_xlabel('$x_1$', loc='right')
    ax.set_xlim(0, 1000)
    ax.set_ylim(0, 2000)
    ax.spines['top'].set_color('gray')
    ax.spines['right'].set_color('gray')
    
    return fig, ax

fig, ax = create_ax()
ax.plot(x, budsjett(1766, 3.03, 1, x), label='Konsumentens budsjett før bompenger', color='#8B0000')  
ax.plot(x, budsjett(1766, 3.61, 1, x), label='Konsumentens budsjett etter bompenger', color='#006400')  
ax.fill_between(x, budsjett(1766, 3.03, 1, x), budsjett(1766, 3.61, 1, x), color="pink", alpha=0.3, label=' mulighetsområde redusert')
ax.set_title('Budsjettbetingelse')
ax.legend(loc='best')

# %% [markdown]
# Ved å bruke estimatene vi har i figuren kan vi se at budsjett betingelsene som viser beregningen hvilke konsument står overfor når han skal velge mellom antall kilometer kjøring og andre goder. Budsjettlinjen representerer da de ulike kombinasjonene av mengder x1 kilometer kjøring og x2 andre goder som konsumenten har budsjett til.
#
# Skjæring mellom budsjettlinjen og x1 aksen markerer den maksimale mengden x1 konsumenten har vil ha råd til hvis han bruker hele budsjettet sitt på gode. Tilsvarende gjelder da for skjæringen med x2 aksjen hvor vi kan finne skjæringen med x1 tar vi setter x2 lik null. Konsumentens mulighetsområde består av kombinasjoner av x 1 og x 2 som ligger mellom budsjettlinjen. Punktet utenfor dette viser området der det ikke er oppnåelig for konsumenten. Figuren viser da budsjettet til en bilist som før og etter innføring av bompenger, der vi kan observere en tydelig endring i budsjettlinjen, der en konsekvens mulighetsområdet reduseres som følge av økte kostnader av bilkjøring. Og det reduserte mulighetsområdet viser da det rosa området mellom de forskjellige linjene.
# Den nye budsjettlinjen får da en brattere helning og skjæringspunkt med x1 aksjen som skyves mot Venstre samtidig som brøken blir mindre. Dette vil da indikere at virkningen av økte kostnader ved forbruk av gode 1 er at konsumenten kjøpekraft blir redusert. En slik effekt vil bli diskutert nærmere oppgaven.

# %%
#Definer symbolene
x_1, x_2, a, b, U_0 =sp.symbols("x_1 x_2 a b U_0", real=True, positive=True)
U=x_1**a*x_2**b
U

#Definer nyttefunksjonen U
x_2_ind_sol=sp.solve(U-U_0,x_2)[0]
x_2_ind_sol

#Løsning for x_2 som funksjon av U_0
indiff_x_2=sp.lambdify( (U_0,a,b,x_1), x_2_ind_sol)
indiff_x_2(U_0,a,b,x_1)

#Konverter en funksjon for plotting
p_1, p_2, m =sp.symbols("p_1 p_2 m", real=True, positive=True)

#Beregn marginal substitusjonsrate
bud=p_1*x_1+p_2*x_2

# Beregne MSB
msb = sp.diff(U, x_1)/sp.diff(U,x_2)

#Løser likning (14) for x_2 som en funksjonen av p_1 og p_2
x_2_rel=sp.solve(msb-p_1/p_2,x_2)[0]

#Setter inn budsjettlikningen for x_1
budsj=bud.subs(x_2,x_2_rel)
x_1_eq= sp.solve(budsj-m,x_1)[0]

#Løsning til likevekt x_2 ved å sette inn x_1_eq i x_2_rel
x_2_eq= x_2_rel.subs(x_1,x_1_eq)

# %% [markdown]
# Regnestykke over kan vi se en utføring av å løse jeg tror ikke at du har et problem som viser nyttefunksjon, budsjettbetingelser og marginal substitusjonsrate i forbruket teori. Den viser da en forbruker teori som beregner det optimale forbruket av 2 goder x1 og x2 under gitt nyttefunksjon av pris og budsjettristriksjoner. Mellom så løser vi ligninger og beregner like vektmengden av godene basert på forbrukernes preferanser har ikke deres økonomiske betingelser.

# %%
#1: Løse x_1_eq og x_2_eq
#2: Beregne U_max, x_1_num og x_2_num
U_max=U.subs([(x_1,x_1_eq),(x_2,x_2_eq)])

#Oppslag med gitte verdier
in_dict = {"a":0.035,"b":0.965,"m":1766,"p_1":3.02,"p_2":1}

#Beregne numeriske verdier
NT=sp.sympify(U_max).evalf(subs={a:in_dict['a'], b:in_dict['b'], m:in_dict['m'], p_1:in_dict['p_1'], p_2:in_dict['p_2']})
x_1_num=sp.sympify(x_1_eq).evalf(subs={a:in_dict['a'], b:in_dict['b'], m:in_dict['m'], p_1:in_dict['p_1'], p_2:in_dict['p_2']})
x_2_num=sp.sympify(x_2_eq).evalf(subs={a:in_dict['a'], b:in_dict['b'], m:in_dict['m'], p_1:in_dict['p_1'], p_2:in_dict['p_2']})

#Beregne numeriske verdier med alternative verdier
NT = U_max.subs([(a,0.049),(b,0.951),(m,1766),(p_1,3.02),(p_2,1)])
x_1_num = x_1_eq.subs([(a,0.049),(b,0.951),(m,1766),(p_1,3.02),(p_2,1)])
x_2_num = x_2_eq.subs([(a,0.049),(b,0.951),(m,1766),(p_1,3.02),(p_2,1)])

NT2 = U_max.subs([(a,0.049),(b,0.951),(m,1766),(p_1,3.61),(p_2,1)])
x_1_num2 = x_1_eq.subs([(a,0.049),(b,0.951),(m,1766),(p_1,3.61),(p_2,1)])
x_2_num2 = x_2_eq.subs([(a,0.049),(b,0.951),(m,1766),(p_1,3.61),(p_2,1)])

display(nytte)
display(x_1_num)
display(x_2_num)
display(nytte2)
display(x_1_num2)
display(x_2_num2)
# Out:
# 1375.75037089129
# 28.6536423841060
# 1679.46600000000
# 1363.77311886464
# 23.9706371191136
# 1679.46600000000

# %% [markdown]
# Vi starter med å finne 2 ligninger, en for den første variabelen og en for den andre variabelen, dermed skal vi bruke nyttefunksjon ved å sette likt ved gitt nyttenivå.
#
# Deretter regner vi maksimale nytt nivå ved å erstatte variablene intervensjonen ved løsningen fra steg én.
#
# I steg 3 skal vi velge et sett med verdier for parameterne. Når vi da bruker disse verdiene i ligningen fra steg én og nyttefunksjonen skal vi beregne det oppnådde nyttenivået også verdiene for variablene. Vi skal da gjenta steg nummer 3 med et annet sett med parameterverdier for å få alternativ nytte og tilhører verdiene for variablene.
#
# Denne regnemåten lar oss beregne nytt nivået og de tilhørte verdiene får variablene basert på de gitte parameterne og et nyttenivå vi kan da sammenligne resultat ved forskjellige parameterne der vi kan se hvordan det påvirker nytten og konsumenten.

# %%
sns.set_theme(style="whitegrid") 

#Lager Plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_ylabel('$x_2$', loc='top', rotation=0, fontsize=14)  
ax.set_xlabel('$x_1$', loc='right', fontsize=14)
ax.set_xlim(0, 1000) #setter Limit 
ax.set_ylim(0, 2000) #setter Limit 
ax.spines['top'].set_color('gray')  
ax.spines['right'].set_color('gray')
ax.plot(x, indiff_x_2(NT, 0.049, 0.951, x), label='$U_{max}$', color='darkred') #før bompenger
ax.plot(x, budsjett(1766, 3.02, 1, x), label='Konsumentens budsjett før bompenger', color='darkgreen')
ax.plot(x, indiff_x_2(NT2, 0.049, 0.951, x), label='$U_{max}$', color='orange') #etter bompenger
ax.plot(x, budsjett(1766, 3.61, 1, x), label='Konsumentens budsjett etter bompenger', color='purple')
ax.vlines(x_1_num, 0, x_2_num, color='gray', ls='dashed', label='$x_1$') #tilpasningen
ax.hlines(x_2_num, 0, x_1_num, color='gray', ls='dashed', label='$x_2$')
ax.vlines(x_1_num2, 0, x_2_num2, color='gray', ls='dashed', label='$x_1$')
ax.hlines(x_2_num2, 0, x_1_num2, color='gray', ls='dashed', label='$x_2$')
ax.set_title('Konsumentens tilpasning', fontsize=16, fontweight='bold', color='black', y=1.05) #tittel
ax.legend(bbox_to_anchor=(1.1, 0.35), fontsize=12)

plt.ylim(1600, 1750)
plt.xlim(15, 40)
# Out:
# (15.0, 40.0)

# %% [markdown]
# Figuren over viser konsumentenes tilpasning innenfor budsjettet forhold nå sitt maksimale nivå konsumentens tilpasning som modell heter også Cobb Douglas modellen og så brukes for å analysere forbrukernes etterspørsel på goder.
#
# Aksjen x1 viser mengden av gode mens y aksen representerer mengden av gode x2.
#
# Budsjettlinjen er det mørkegrønne og lilla linjen som representerer konsument sett budsjett før og etter bompenger. De viser kombinasjonen av x1 og x2 som konsumenten har råd til gitt prisene på gode som sitt totale.
#
# Maksimalt nytt nivå er den mørkerøde og oransje kurven som representerer da det maksimale nyttenivået som konsumenten eventuelt kan oppnå, kurven viser kombinasjonen av x1 og x2 som gir konsumenten høy snittet gitt nytt divisjon og restriksjoner.
#
# Tilpasning er vist i de grå linjene som viser konsumentens tilpasning, vertikalt stiplede linjen markerer x1 verdien det er en konsument forbruker.  Den horisontale strippeline markerer x2 verdien, disse linjene viser kombinasjonen som konsumenten velger å maksimere nytten ved et budsjett.
#
# Estimater får kostnader budsjett har vi funnet for å estimere kostnaden på budsjettet i budsjettbetingelsen. Disse estimatene er viktig for å analysere forbrukernes valg og tilpasning.
# Nytt preferanse er viktig for faktoren i forbrukernes valg. Jeg har valgt verdier for hytteprat sånn som passer med det vi vet om bilister i Tromsø. Dette vil gjøre at delen kan gi en realistisk spiller på forbrukernes adferd. Prisens innvirkning er en faktor som påvirkes av forbrukernes etterspørsel. Når en pris øker vil en etterspørsel vanligvis synke. Der konsumenten tilpasser seg og reduserer antall kjørte kilometer når bompengene innføres slik vi ser det figuren. Uavhengig av mellom modellen er det ingen krysspriselastisitet soma vil si at endringer i prisen på et gode ikke kan påvirke konsumenter av andre gode. Elastiteten for kjørelengde avhenger av substitusjons mulighetene om hvor stor andel budsjett som brukes av et konsum vedkjøring. Hvis det er mulig å bytte personbiltransport med andre transportmidler OK andel av budsjettet som brukes på kjøring er stor vil en eventuell etterspørsel være mer elastisk. Som posisjonen effekt og inntekt her prisen når kjøring øker, fyll en etterspørsel etter alternative goder øke på grunn av substitusjonseffekt. Dette samtidig påvirker prisøkningen på konsumgruppen kjøpekraft noe som vil representere inntektseffekten.
#
# Sammensatt gir modellen en teoretisk ramme hvor analysere forbrukernes valg og tilpasning i lys av pris, budsjett og nytte preferanser. Modellen la oss få en innsikt på hvordan endringer i disse faktorene kan påvirke forbrukernes adferd og etterspørsel etter goder.

# %%
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(12, 8))
ax.set_ylabel('$x_2$', loc='top', rotation=0, fontsize=14)
ax.set_xlabel('$x_1$', loc='right', fontsize=14)
ax.set_xlim(0, 1000)
ax.set_ylim(0, 2000)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#før bompenger
ax.plot(x, indiff_x_2(NT, 0.049, 0.951, x), label='$U_{max}$', color='darkred')
ax.plot(x, budsjett(1766, 3.02, 1, x), label='Budsjett før bompenger', color='darkgreen')

#etter bompenger
ax.plot(x, indiff_x_2(NT2, 0.049, 0.951, x), label='$U_{max}$', color='orange')
ax.plot(x, budsjett(1766, 3.61, 1, x), label='Budsjett etter bompenger', color='purple')

#forskyvning av budsjett 
komp = NT/NT2 #setter sammen figurer med to nyttefunksjoenr
nyttbudsjett = 1766 * komp
ax.plot(x, budsjett(nyttbudsjett, 3.61, 1, x), label='Budsjett kompensert', color='blue')
x_1_num_komp = x_1_eq.subs([(a, 0.049), (b, 0.951), (m, nyttbudsjett), (p_1, 3.61), (p_2, 1)])
x_2_num_komp = x_2_eq.subs([(a, 0.049), (b, 0.951), (m, nyttbudsjett), (p_1, 3.61), (p_2, 1)])
ax.vlines(x_1_num, 0, x_2_num, color='gray', ls='dashed', label='$x_1$ før bompenger') #tilpasningen
ax.hlines(x_2_num, 0, x_1_num, color='gray', ls='dashed', label='$x_2$ før og etter bompenger')
ax.vlines(x_1_num2, 0, x_2_num2, color='red', ls='dashed', label='$x_1$ etter bompenger')
ax.hlines(x_2_num2, 0, x_1_num2, color='gray', ls='dashed')
ax.vlines(x_1_num_komp, 0, x_2_num_komp, color='blue', ls='dashed', label='$x_1$ kompensert')
ax.hlines(x_2_num_komp, 0, x_1_num_komp, color='blue', ls='dashed', label='$x_2$ kompensert')
ax.vlines(x_1_num, 0, x_2_num, color='gray', ls='dashed', label='$x_1$')
ax.hlines(x_2_num, 0, x_1_num, color='gray', ls='dashed', label='$x_2$')
ax.vlines(x_1_num2, 0, x_2_num2, color='gray', ls='dashed', label='$x_1$')
ax.hlines(x_2_num2, 0, x_1_num2, color='gray', ls='dashed', label='$x_2$')
ax.set_title('Substitusjons og inntektseffekt', fontsize=16, fontweight='bold', color='black', y=1.05) #tittel
ax.legend(bbox_to_anchor=(1.1, 0.35), fontsize=12) #viser navnene
ax.annotate('A', xy=(x_1_num, x_2_num + 1), size=10, fontweight='bold') #punkter på graf
ax.annotate('B', xy=(x_1_num2 - 0.05, x_2_num2 + 1), size=10, fontweight='bold')
ax.annotate('C', xy=(x_1_num_komp, x_2_num_komp + 1), size=10, fontweight='bold')

plt.ylim(1650, 1710)
plt.xlim(22, 30)
plt.show()

# %% [markdown]
# Substitusjonseffekten og inntektseffekten refererer til endringer i etterspørselen etter at gode som følge av endringer i pris på en annen kode, holdt da av at inntekten er konstant. Prisen på kjøring øker som følge av bompenger vil da kjøring bli dyrere i forhold til at andre goder. I tilfelle kan dette føre til at forbrukerne velger redusere sin kjørelengde i stedet for å benytte alternativet transportleder eller resultere med å redusere sitt totale forbruk. Substitusjonseffekten indikerer det her med den bevegelse i internettjeneste kurven mot kombinasjoner av kode som er billigere i forhold med kjøring
#
# Inntektseffekten er det derimot om endring i etterspørselen etter et gode som er følge av endringer i forbrukernes inntekt. Ettersom at mer penger blir brukt på bompenger og mindre penger blir tilgjengelig for kjøp av andre koder. Dette kan gi en reduksjon i forbrukerne av alle goder. Inntektseffekten vil føre til en bevegelse i interferensen kurven innover og i et lavere nyttenivå.
#
# Forholdet med bomringer og Tromsø er at stasjons effekten og inntektseffekten vil da hjelpe oss med å forstå hvordan forbrukernes kjøreatferd endrer. Substitusjonseffekten viser forbrukerne kan velge antall alternativ i transportformer eller reduserer kjørelengden for å unngå økte kostnader ved bomring.
#
# I grafen over kan vi se rundt stasjonen og hvordan innføring av bompenger kan påvirke forbrukernes tilpasning. Vi kan se at forbrukeren har redusert antall kjørte kilometer etter innføringen av bompenger. Det vil da resulterer med at stasjons effekten der forbrukeren benytter utkjøringer og andre goder er relativt billigere. Inntektseffekten viser hvordan bompengene påvirker forbrukernes kjøpekraft som kan gi en reduksjon i nyttenivået. Grafen viser også da en konkurrerte tilpasning der budsjettet er justert for å opprettholde samme nyttenivå som bompenger. Dette illustrerer jo da reaksjon fra forbrukeren som gjør at de unngår en reduksjon i nytte følge av innføring av bompenger

# %%
subtitusjonseffekten  = x_1_num-x_1_num2
display(subtitusjonseffekten)
inntektseffekten = x_1_num2-x_1_num_komp
display(inntektseffekten)
totaleffekten = x_1_num-x_1_num_komp
display(totaleffekten)
# Out:
# 4.68300526499239
# -0.210520619627665
# 4.47248464536472

# %% [markdown]
# Resultat på substitusjonseffekten er beregnet på 4.68300526499239 som vi betyr at innføring av bompenger i Tromsø fører til en økning i substitusjon mellom kjøring og andre goder det vil gjøre at forbrukerne reduserer sin kjørelengde og erstatter det med andre alternativer på grunn av kostnader som har økt.
#
# Inntektseffekten resulterer med -0.210520619627665 som er negativt som indikerer da at innføringen av bompenger reduserer forbrukernes det spinale inntekt og dermed deres evne til å kjøpe, både kjøring og andre goder.
#
# Totaleffekten er beregnet på 4.472484645364724.47248464536472 som er summen av substitusjonseffekt og inntektseffekten, da er det viser den totale effekten av innføring av bompenger i Tromsø er en netto endring i forbrukerne for avferd og nytte, men også en reduksjon i kjørelengden og en påvirkning i kjøpekraften
#
# I samlet resultat viser det er at innføring av bompenger i Tromsø både en som substitusjonseffekt og en inntektseffekt for forbrukeres adferd. Forbruker har da klart å tilpasse seg ved å redusere kjørelengde og endre forbrukermønstre på grunn av dyre transportmuligheter/ kostnader. Samtidig påvirkes dissosial ale inntekt som er negativt sånn kan ha konsekvenser for deres totale forbruk i kjøring.

# %% [markdown]
# ## Avslutningsvis kan vi konkludere med følgende

# %% [markdown]
# Av informasjon og data som vi har diskutert i analysen vil jeg komme frem med følgende konklusjoner:
#
# Etter nøye observering av analysen så går vi se en økt trend i endringer i bilstatferd. Innføringen av bompengene har gjort en merkbar endring. Bilister har da valgt å endre reiseruter for å unngå bomstasjoner, samt at andre har redusert antall turer som de tar med bil, dette vil da resultere med da reduksjon i biltrafikk rundt Tromsø.
#
# Økning i bruk av offentlig transport har hvis den økning. Bompenger har også oppsummert flere så da tar transport av andre metoder, de sykler eller går, dette er da en mer kostnadseffektivt alternativ.
#
# Miljøpåvirkning på lang sikt har vi fått en reduksjon i biltrafikk som da bidrar til å redusere luftforurensning. Dette vil da ha langtids positive effekter på miljøet hvis dette fortsetter.
#
# Det har også vist økonomisk belastning for bilister der det er negativt at bompenger har lagt til ekstra økonomisk belastning på billigste, og dette er spesielt for de som er avhengig av å bruke bil daglig. Dette innfører da bekymringer og sosial rettferdighet og økonomisk velferd av disse individene. Jeg er så god
#
# I sin helhet så kan vi se på innføringen av bompenger i Tromsø har hatt sine positive og negative effekter. Dette kan være en sak som har vært observere og evaluere i lengre tid for å sikre balansert og rettferdig transportpolitikk.
#
#
#
# #### Kilder:
#
# Tenk Tromsø: https://tenktromso.no/
#
# Road Tolls of Norway: https://www.toi.no/getfile.php?mmfileid=73593
#
# Transportøkonomisk Institutt: https://www.toi.no/
#
# Trafikkdata: https://www.vegvesen.no/trafikkdata/start/eksport?datatype=DAY&from=2023-04-19&lat=69.667062921797&lon=18.972969608631402&registrationFrequencies=&to=2023-04-20&trafficType=vehicle&zoom=10
#
# Ressursbank i transportsektoren: https://www.ntnu.no/documents/1261860271/1262010703/Concept_Nr44_no-ny.pdf/e6b903f5-b438-40f1-90d5-aeac5deb5472
#
# SSB: https://www.ssb.no/ssb-skole/den-norske-arbeidsmarknaden
